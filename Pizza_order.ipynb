# %% [markdown]
# ## Pizza Order

# %% [markdown]
# #### Test 1 - Height dosen't meet condition, code won't print ticket and height should be above 121cm
#
# (height >= 121)

# %%
print("Hello, Welcome to python-counter")
print("What is your name?")
name = input()
print(f"nice to meet you {name}, My name is harry")
print()
print("what is your height in cm?")
height = int(input())
a, b, c, d = 5, 7, 12, 3
height_v2 = height >= 121
if height_v2:
    print(f"your height is {height}, and you can ride today")
    print()
    print("What is your age?")
    age = int(input())
    if age < 12:
        print(f"you are {age} year old, and your ticket will be £{a}.")
        print()
        print("Do you want photo ticket?")
        print()
        print(f"In capital letter Y for yes and N for no")
        photo = input()
        if photo == "Y":
            print(f"your ticket plus photo will be £{int(a+d)}")
        else:
            print(f"Have a nice day and your grand total will be £{int(a)} ")
    elif age <= 18:
        print(f"you are {age} year old, and your ticket will be £{b}.")
        print()
        print("Do you want photo ticket?")
        print()
        print(f"In capital letter Y for yes and N for no")
        photo = input()
        if photo == "Y":
            print(f"your ticket plus photo will be £{int(b+d)}")
        else:
            print(f"Have a nice day and your grand total will be £{int(b)}")
    elif age > 18:
        print(f"you are {age} year old, and your ticket will be £{c}.")
        print()
        print("Do you want photo ticket?")
        print()
        print(f"In capital letter Y for yes and N for no")
        photo = input()
        if photo == "Y":
            print(f"your ticket plus photo will be £{int(c+d)}")
        else:
            print(f"Have a nice day and your grand total will be £{int(c)}")
else:
    print(f"Sorry try next time, you height is {height} cm and you aren't tall enough to ride today")
print()
print("Hopefully, you enjoyed it")
print()
print("follow me for more: https://www.linkedin.com/in/thapahemant/")
# Out:
# Hello, Welcome to python-counter
# What is your name?
# Thapa
# nice to meet you Thapa, My name is harry
#
# what is your height in cm?
# 100
# Sorry try next time, you height is 100 cm and you aren't tall enough to ride today
#
# Hopefully, you enjoyed it
#
# follow me for more: https://www.linkedin.com/in/thapahemant/

# %% [markdown]
# #### Test 2 - c-Case one of Print ticket and fair

# %%
print("Hello, Welcome to python-counter")
print("What is your name?")
name = input()
print(f"nice to meet you {name}, My name is harry")
print()
print("what is your height in cm?")
height = int(input())
a, b, c, d = 5, 7, 12, 3
height_v2 = height >= 121
if height_v2:
    print(f"your height is {height}, and you can ride today")
    print()
    print("What is your age?")
    age = int(input())
    if age < 12:
        print(f"you are {age} year old, and your ticket will be £{a}.")
        print()
        print("Do you want photo ticket?")
        print()
        print(f"In capital letter Y for yes and N for no")
        photo = input()
        if photo == "Y":
            print(f"your ticket plus photo will be £{int(a+d)}")
        else:
            print(f"Have a nice day and your grand total will be £{int(a)} ")
    elif age <= 18:
        print(f"you are {age} year old, and your ticket will be £{b}.")
        print()
        print("Do you want photo ticket?")
        print()
        print(f"In capital letter Y for yes and N for no")
        photo = input()
        if photo == "Y":
            print(f"your ticket plus photo will be £{int(b+d)}")
        else:
            print(f"Have a nice day and your grand total will be £{int(b)}")
    elif age > 18:
        print(f"you are {age} year old, and your ticket will be £{c}.")
        print()
        print("Do you want photo ticket?")
        print()
        print(f"In capital letter Y for yes and N for no")
        photo = input()
        if photo == "Y":
            print(f"your ticket plus photo will be £{int(c+d)}")
        else:
            print(f"Have a nice day and your grand total will be £{int(c)}")
else:
    print(f"Sorry try next time, you height is {height} cm and you aren't tall enough to ride today")
print()
print("Hopefully, you enjoyed it")
print()
print("follow me for more: https://www.linkedin.com/in/thapahemant/")
# Out:
# Hello, Welcome to python-counter
# What is your name?
# Thapa
# nice to meet you Thapa, My name is harry
#
# what is your height in cm?
# 167
# your height is 167, and you can ride today
#
# What is your age?
# 10
# you are 10 year old, and your ticket will be £5.
#
# Do you want photo ticket?
#
# In capital letter Y for yes and N for no
# N
# Have a nice day and your grand total will be £5
#
# Hopefully, you enjoyed it
#
# follow me for more: https://www.linkedin.com/in/thapahemant/

# %% [markdown]
# #### Test 3 - Case two of Print ticket and fair

# %%
print("Hello, Welcome to python-counter")
print("What is your name?")
name = input()
print(f"nice to meet you {name}, My name is harry")
print()
print("what is your height in cm?")
height = int(input())
a, b, c, d = 5, 7, 12, 3
height_v2 = height >= 121
if height_v2:
    print(f"your height is {height}, and you can ride today")
    print()
    print("What is your age?")
    age = int(input())
    if age < 12:
        print(f"you are {age} year old, and your ticket will be £{a}.")
        print()
        print("Do you want photo ticket?")
        print()
        print(f"In capital letter Y for yes and N for no")
        photo = input()
        if photo == "Y":
            print(f"your ticket plus photo will be £{int(a+d)}")
        else:
            print(f"Have a nice day and your grand total will be £{int(a)} ")
    elif age <= 18:
        print(f"you are {age} year old, and your ticket will be £{b}.")
        print()
        print("Do you want photo ticket?")
        print()
        print(f"In capital letter Y for yes and N for no")
        photo = input()
        if photo == "Y":
            print(f"your ticket plus photo will be £{int(b+d)}")
        else:
            print(f"Have a nice day and your grand total will be £{int(b)}")
    elif age > 18:
        print(f"you are {age} year old, and your ticket will be £{c}.")
        print()
        print("Do you want photo ticket?")
        print()
        print(f"In capital letter Y for yes and N for no")
        photo = input()
        if photo == "Y":
            print(f"your ticket plus photo will be £{int(c+d)}")
        else:
            print(f"Have a nice day and your grand total will be £{int(c)}")
else:
    print(f"Sorry try next time, you height is {height} cm and you aren't tall enough to ride today")
print()
print("Hopefully, you enjoyed it")
print()
print("follow me for more: https://www.linkedin.com/in/thapahemant/")
# Out:
# Hello, Welcome to python-counter
# What is your name?
# Thapa
# nice to meet you Thapa, My name is harry
#
# what is your height in cm?
# 167
# your height is 167, and you can ride today
#
# What is your age?
# 16
# you are 16 year old, and your ticket will be £7.
#
# Do you want photo ticket?
#
# In capital letter Y for yes and N for no
# N
# Have a nice day and your grand total will be £7
#
# Hopefully, you enjoyed it
#
# follow me for more: https://www.linkedin.com/in/thapahemant/

# %% [markdown]
# #### Test 4 - Case three of print ticket and fair

# %%
print("Hello, Welcome to python-counter")
print("What is your name?")
name = input()
print(f"nice to meet you {name}, My name is harry")
print()
print("what is your height in cm?")
height = int(input())
a, b, c, d = 5, 7, 12, 3
height_v2 = height >= 121
if height_v2:
    print(f"your height is {height}, and you can ride today")
    print()
    print("What is your age?")
    age = int(input())
    if age < 12:
        print(f"you are {age} year old, and your ticket will be £{a}.")
        print()
        print("Do you want photo ticket?")
        print()
        print(f"In capital letter Y for yes and N for no")
        photo = input()
        if photo == "Y":
            print(f"your ticket plus photo will be £{int(a+d)}")
        else:
            print(f"Have a nice day and your grand total will be £{int(a)} ")
    elif age <= 18:
        print(f"you are {age} year old, and your ticket will be £{b}.")
        print()
        print("Do you want photo ticket?")
        print()
        print(f"In capital letter Y for yes and N for no")
        photo = input()
        if photo == "Y":
            print(f"your ticket plus photo will be £{int(b+d)}")
        else:
            print(f"Have a nice day and your grand total will be £{int(b)}")
    elif age > 18:
        print(f"you are {age} year old, and your ticket will be £{c}.")
        print()
        print("Do you want photo ticket?")
        print()
        print(f"In capital letter Y for yes and N for no")
        photo = input()
        if photo == "Y":
            print(f"your ticket plus photo will be £{int(c+d)}")
        else:
            print(f"Have a nice day and your grand total will be £{int(c)}")
else:
    print(f"Sorry try next time, you height is {height} cm and you aren't tall enough to ride today")
print()
print("Hopefully, you enjoyed it")
print()
print("follow me for more: https://www.linkedin.com/in/thapahemant/")
# Out:
# Hello, Welcome to python-counter
# What is your name?
# Thapa
# nice to meet you Thapa, My name is harry
#
# what is your height in cm?
# 167
# your height is 167, and you can ride today
#
# What is your age?
# 24
# you are 24 year old, and your ticket will be £12.
#
# Do you want photo ticket?
#
# In capital letter Y for yes and N for no
# N
# Have a nice day and your grand total will be £12
#
# Hopefully, you enjoyed it
#
# follow me for more: https://www.linkedin.com/in/thapahemant/

# %% [markdown]
# #### Test 5 - Ticket plus photo

# %%
print("Hello, Welcome to python-counter")
print("What is your name?")
name = input()
print(f"nice to meet you {name}, My name is harry")
print()
print("what is your height in cm?")
height = int(input())
a, b, c, d = 5, 7, 12, 3
height_v2 = height >= 121
if height_v2:
    print(f"your height is {height}, and you can ride today")
    print()
    print("What is your age?")
    age = int(input())
    if age < 12:
        print(f"you are {age} year old, and your ticket will be £{a}.")
        print()
        print("Do you want photo ticket?")
        print()
        print(f"In capital letter Y for yes and N for no")
        photo = input()
        if photo == "Y":
            print(f"your ticket plus photo will be £{int(a+d)}")
        else:
            print(f"Have a nice day and your grand total will be £{int(a)} ")
    elif age <= 18:
        print(f"you are {age} year old, and your ticket will be £{b}.")
        print()
        print("Do you want photo ticket?")
        print()
        print(f"In capital letter Y for yes and N for no")
        photo = input()
        if photo == "Y":
            print(f"your ticket plus photo will be £{int(b+d)}")
        else:
            print(f"Have a nice day and your grand total will be £{int(b)}")
    elif age > 18:
        print(f"you are {age} year old, and your ticket will be £{c}.")
        print()
        print("Do you want photo ticket?")
        print()
        print(f"In capital letter Y for yes and N for no")
        photo = input()
        if photo == "Y":
            print(f"your ticket plus photo will be £{int(c+d)}")
        else:
            print(f"Have a nice day and your grand total will be £{int(c)}")
else:
    print(f"Sorry try next time, you height is {height} cm and you aren't tall enough to ride today")
print()
print("Hopefully, you enjoyed it")
print()
print("follow me for more: https://www.linkedin.com/in/thapahemant/")
# Out:
# Hello, Welcome to python-counter
# What is your name?
# Thapa
# nice to meet you Thapa, My name is harry
#
# what is your height in cm?
# 167
# your height is 167, and you can ride today
#
# What is your age?
# 24
# you are 24 year old, and your ticket will be £12.
#
# Do you want photo ticket?
#
# In capital letter Y for yes and N for no
# Y
# your ticket plus photo will be £15
#
# Hopefully, you enjoyed it
#
# follow me for more: https://www.linkedin.com/in/thapahemant/
